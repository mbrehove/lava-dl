# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle
with open('run_eth_output.pkl', 'rb') as f:
    output = pickle.load(f)

# %%
output[20]
# Out:
# <PIL.Image.Image image mode=RGB size=896x448>
